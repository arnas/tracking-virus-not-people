# %%
import pandas as pd
import numpy as np
import json

# %%
data_path_1 = 'Data/2020_MARCH.json'
data_path_2 = 'Data/2020_FEBRUARY.json'

# %%
def location_history_processing_pipeline(raw_json_file_locations):
    raw_json = concat_src_files(raw_json_file_locations)
    places_df, location_df = extract_location_information_from_raw(raw_json)
    return location_df

# %%
def concat_src_files(raw_json_file_locations):
    all_data = []
    for file in raw_json_file_locations:
        print(file)
        json_data = json.load(open(file, 'rb'))
        all_data += json_data['timelineObjects']
    return {'timelineObjects': all_data}

# %%
def extract_location_information_from_raw(raw_json):
    places_data = []
    location_data = []

    for json_dict in raw_json['timelineObjects']:
        if "placeVisit" in json_dict:
            places_data.append(json_dict['placeVisit'])
            location_dict = json_dict['placeVisit']['location']
            location_dict['visit_start_time'] = json_dict['placeVisit']['duration']['startTimestampMs']
            location_dict['visit_end_time'] = json_dict['placeVisit']['duration']['endTimestampMs']
            location_data.append(location_dict)
    return pd.DataFrame(places_data), pd.DataFrame(location_data)

# %%
df1 = location_history_processing_pipeline([data_path_1, data_path_2])
# Out:
# Data/2020_MARCH.json
# Data/2020_FEBRUARY.json

# %%
df1
# Out:
#      latitudeE7  longitudeE7                      placeId  \
# 0     547020301    252894199  ChIJv8Qx96iW3UYR8uQowtBII2s
# 1     547022084    252841645  ChIJa_EGkKmW3UYRhE0AXwxbZ68
# 2     547020301    252894199  ChIJv8Qx96iW3UYR8uQowtBII2s
# 3     547022084    252841645  ChIJa_EGkKmW3UYRhE0AXwxbZ68
# 4     546849651    252812342  ChIJj4V6ChGU3UYRtj8nUsFTK6Q
# ..          ...          ...                          ...
# 180   547022084    252841645  ChIJa_EGkKmW3UYRhE0AXwxbZ68
# 181   546883542    252732445  ChIJ_6hwBQ-U3UYRcfhfR20teh0
# 182   546910952    252637137  ChIJC3tstQmU3UYRRD_9JDG1jlw
# 183   546938630    252761760  ChIJuVPQWQeU3UYRXAwMHdJz_l8
# 184   547022084    252841645  ChIJa_EGkKmW3UYRhE0AXwxbZ68
#
#                                      address  \
# 0    Tuskulėnų g. 66\nVilnius 09208\nLietuva
# 1       Trimitų g. 3\nVilnius 09318\nLietuva
# 2    Tuskulėnų g. 66\nVilnius 09208\nLietuva
# 3       Trimitų g. 3\nVilnius 09318\nLietuva
# 4      Labdarių g. 5\nVilnius 01120\nLietuva
# ..                                       ...
# 180     Trimitų g. 3\nVilnius 09318\nLietuva
# 181  Gedimino pr. 31\nVilnius 01104\nLietuva
# 182  Gedimino pr. 51\nVilnius 01109\nLietuva
# 183        Upės g. 9\nVilnius 09308\nLietuva
# 184     Trimitų g. 3\nVilnius 09318\nLietuva
#
#                                                 name  \
# 0                                          Maxima XX
# 1                                       Trimitų g. 3
# 2                                          Maxima XX
# 3                                       Trimitų g. 3
# 4                                      Labdarių g. 5
# ..                                               ...
# 180                                     Trimitų g. 3
# 181                                     DRAMA BURGER
# 182  Martynas Mažvydas National Library of Lithuania
# 183                             Prekybos centras CUP
# 184                                     Trimitų g. 3
#
#                      sourceInfo  locationConfidence visit_start_time  \
# 0    {'deviceTag': -1460497777}            99.49381    1583069925781
# 1    {'deviceTag': -1460497777}            65.31114    1583072571248
# 2    {'deviceTag': -1460497777}            97.42366    1583084327524
# 3    {'deviceTag': -1460497777}            66.15688    1583085140052
# 4    {'deviceTag': -1460497777}            92.86199    1583135036319
# ..                          ...                 ...              ...
# 180  {'deviceTag': -1460497777}            56.08359    1582913210364
# 181  {'deviceTag': -1460497777}            85.30062    1582985150817
# 182  {'deviceTag': -1460497777}            99.29467    1582987680111
# 183  {'deviceTag': -1460497777}            75.42997    1582991119745
# 184  {'deviceTag': -1460497777}            64.55895    1582992901138
#
#     visit_end_time           semanticType
# 0    1583072170250                    NaN
# 1    1583084144659  TYPE_SEARCHED_ADDRESS
# 2    1583084852708                    NaN
# 3    1583133628107  TYPE_SEARCHED_ADDRESS
# 4    1583143231520                    NaN
# ..             ...                    ...
# 180  1582983844395  TYPE_SEARCHED_ADDRESS
# 181  1582987284398                    NaN
# 182  1582990385750                    NaN
# 183  1582991825991                    NaN
# 184  1583069728570  TYPE_SEARCHED_ADDRESS
#
# [185 rows x 10 columns]
